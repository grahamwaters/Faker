# %% [markdown]
# What if we want to populate a CRM database with fake data?
# Let's assume this is our schema:
# ```markdown
# - Person
#     - first_name
#     - last_name
#     - email
#     - phone
#     - address
#     - city
#     - state
#     - zip
#     - country
#     - company
#     - job_title
#     - notes
# ```
# and we want to populate it with synthetic data. We can use faker as shown below to do this.

# %%
# Out:
#   first_name last_name  account_number                  email
# 0     Stacey    Moreno      3564912336      icook@example.org  \
# 1     Joseph   Johnson      3244605011  graykelly@example.com
# 2      Shane    Palmer      4003413023     mary89@example.com
# 3     Karina      Rose      8644207015   martha37@example.org
# 4    Destiny    Watson      3442067522  rwilliams@example.net
#
#             phone_number                                           address
# 0             5440869623  953 Gray Tunnel, East Christopherville, DC 68762  \
# 1     598.067.9415x59051         048 Martin Shoal, Andersonville, NC 04169
# 2           269.418.9232     6171 Allen Cove Suite 007, Erinland, WA 60942
# 3  001-531-441-1945x9871              585 Johnson Spur, Tammyton, NC 41539
# 4           590.905.6611          3722 Alexis Locks, Lake Robert, MP 53936
#
#              city      state zipcode date_of_birth   amount
# 0  Hernandezmouth   Illinois   35723    1987-06-14  2691.57  \
# 1      Hansentown   Michigan   50204    1942-07-07  6557.66
# 2   Harrisonmouth     Kansas   75989    1970-03-21  9112.93
# 3     New Michele   Kentucky   34593    1949-04-06  6188.71
# 4      Justinview  Louisiana   09075    1996-07-23  3814.77
#
#                 account_name                 account_email
# 0                  Allen LLC      nmurray@jackson-bell.org  \
# 1             Davis and Sons  andrew30@callahan-jacobs.com
# 2             Gray-Rodriguez              ulewis@rose.info
# 3  Woods, Cordova and Conner        justinblair@wilson.biz
# 4             Greer and Sons       clarkallison@rivas.info
#
#          account_phone                                 account_address
# 0     009.985.3063x029  06355 Joan Crest Apt. 253, East Ryan, AS 26231  \
# 1         636-356-7017          308 Michael Rapids, East Amy, RI 35592
# 2  +1-165-772-3577x085                       USCGC Reese, FPO AA 60907
# 3         093.811.8000  30425 Joshua Corner, Villanuevashire, AZ 20473
# 4    (672)440-8808x223          5603 Drew Pike, West Melanie, MO 03851
#
#          account_city account_state account_zipcode account_status
# 0     South Craigberg  North Dakota           95793         active  \
# 1         Richardland     Louisiana           43474         active
# 2           New Henry      Virginia           11690       inactive
# 3  North Barbaraburgh     Louisiana           67181         active
# 4         Staceyville    New Mexico           45947       inactive
#
#   account_start_date account_end_date  account_amount
# 0         2019-06-12       2026-03-16        20816.26
# 1         2019-08-09       2023-09-30        14683.71
# 2         2022-12-12       2025-07-26        42854.68
# 3         2019-09-26       2024-11-27        25585.39
# 4         2022-05-05       2027-09-14        19491.88
